# %%
import pandas as pd

data = pd.read_csv("/Users/brunoinzunza/Documents/GitHub/BAT/research/optimization_results_20251021_142655.csv")

data
# Out:
#    rank  sma_period  std_multiplier  train_pnl  train_trades  train_win_rate  \
# 0     1           3             0.4   71721.14          5933           68.67
# 1     2           3             0.3   71120.27          6020           68.39
# 2     3           3             0.5   70249.04          5808           68.75
# 3     4           4             1.5   70102.06          2755           70.20
# 4     5           3             0.6   69910.99          5697           68.86
# 5     6           3             0.2   69642.87          6078           67.95
# 6     7           4             0.5   69395.98          4951           69.88
# 7     8           4             0.7   69354.81          4652           69.93
# 8     9           3             0.1   69305.17          6152           67.91
# 9    10           4             0.6   69191.25          4787           69.96
#
#     val_pnl  val_trades  val_win_rate  test_pnl  test_trades  test_win_rate  \
# ...
